# %% [markdown]
# # 2022 ML Exam
#
# STUDENTID: mv313

# %% [markdown]
# # Part I: Adult Dataset

# %% [markdown]
# Uncomment cell bellow if libraries need to be installed.

# %%
#!pip install aif360
#!pip install fairlearn
#!pip install tensorflow

# %% [markdown]
# # AdultDataset

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from aif360.datasets import AdultDataset
from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions import load_preproc_data_adult
from aif360.algorithms.preprocessing.reweighing import Reweighing
from aif360.metrics import ClassificationMetric 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.svm import SVC

np.random.seed(42)

# %%
# cd \usr\lib\aif360\data\raw\adult

# %%
# Representation of a standard ML classification

dataset_orig = load_preproc_data_adult(['sex'])
priv = [{'sex': 1}]
unpriv = [{'sex': 0}]
train, test = dataset_orig.split([0.7], shuffle=True)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(train.features)
y_train = train.labels.ravel()
X_test = scaler.transform(test.features) 
y_test = test.labels.ravel()
clf = LogisticRegression(solver='liblinear', C = 0.5, random_state=1)  
clf.fit(X_train,y_train)
predictions = clf.predict(X_test)
test_pred = test.copy()
test_pred.labels = predictions
acc = sum(predictions==y_test)/len(y_test)
print (acc)
# Out:
# 0.8039991810550741

# %% [markdown]
# # From the start

# %%
ds = AdultDataset()
dataset_orig = load_preproc_data_adult(['sex'])
priv = [{'sex': 1}]
unpriv = [{'sex': 0}]
train, test = dataset_orig.split([0.7], shuffle=True)
scaler = MinMaxScaler()
# Out:
# WARNING:root:Missing Data: 3620 rows removed from AdultDataset.

# %%
def return_af_tradeoff(acc, eo):
    ftd = (1 - abs(eo) + acc)/2
    return ftd

# %%
def ret_folds(train, k = 5):
    f1, f2, f3, f4, f5 = train.split(k, shuffle = True)
    folds = [f1, f2, f3, f4, f5]
    return folds

def eval_k_fold(train, clf, rw=None,k=5):
    
    if rw: 
        train = rw.fit_transform(train)
        
    train_folds = ret_folds(train)
    averages = [0, 0, 0]
    eq_opps = []
    tradeoffs = []
    accuracies = []
    true_ys = []
    y_preds = []
    metrics = {}
    k_test = train_folds[0]
    
    for i in range(k-1, -1, -1):
        for j in range(k-1):
            if j == 0:
                X_train = scaler.fit_transform(train_folds[j].features)
                y_train = train_folds[j].labels.ravel()
                sw = train_folds[j].instance_weights
                true_ys = np.concatenate((y_train, true_ys))
            else:
                if j == i:
                    pass
                else:
                    X_train = np.concatenate((X_train, scaler.fit_transform(train_folds[j].features)))
                    y_train = np.concatenate((y_train, train_folds[j].labels.ravel()))
                    sw = np.concatenate((sw, train_folds[j].instance_weights))
                    true_ys = np.concatenate((true_ys, train_folds[j].labels.ravel()))
        
        X_test = scaler.transform(k_test.features)
        y_test = k_test.labels.ravel()
        clf.fit(X_train, y_train, sample_weight = sw)
        predictions = clf.predict(k_test.features)
        test_pred = k_test.copy()
        test_pred.labels = predictions
        y_preds = np.concatenate((y_preds, test_pred.labels))
        
        metric = ClassificationMetric(k_test, test_pred, unprivileged_groups=unpriv, privileged_groups=priv)
        eo = (metric.equal_opportunity_difference())
        metrics["Fold " + str(i+1) + " metrics"] = {"eq_opp_diff": eo}
        metrics["Fold " + str(i+1) + " metrics"]["accuracy"] = acc = sum(predictions==k_test.labels.ravel())/len(k_test.labels.ravel())
        metrics["Fold " + str(i+1) + " metrics"]["tradeoff"] = return_af_tradeoff(acc, eo)
        
        eq_opps = np.append(eq_opps, eo)
        accuracies = np.append(accuracies, acc)
        tradeoffs = np.append(tradeoffs, return_af_tradeoff(acc, eo))
        
        averages[0] += sum(predictions==k_test.labels.ravel())/len(k_test.labels.ravel())
        averages[1] += (metric.equal_opportunity_difference())
        averages[2] += return_af_tradeoff(acc, eo)
        
        k_test = train_folds[i]
        
    averages = {'mean_acc': averages[0]/k, 'avg_tradeoff': averages[2]/k, 'mean_eq_opp': averages[1]/k}  # Get the average of all the folds.
    ys = {'predicted_ys' : y_preds, 'true_ys' : true_ys}

        
    return metrics, averages, ys, eq_opps

# %%
def eval_log_reg(train, silence_print = False, rw = None):
    eo_avgs = []
    acc_avgs = []
    tradeoff_avgs=[]
    models = {}
    
    for solver in logreg_solvers:
        for c in C:
            metrics, averages, ys, eq_opps = eval_k_fold(train, clf = LogisticRegression(solver = solver, C = c), rw = rw)
            models[f'{solver}_LogReg_{c}'] = {'averages':averages}
            models[f'{solver}_LogReg_{c}']['metrics'] = metrics
            models[f'{solver}_LogReg_{c}']['ys'] = ys
            models[f'{solver}_LogReg_{c}']['eq_opps'] = eq_opps
            
            if not silence_print:
                print (f"Results for LogReg with C = {c}, and solver = {solver} : \n \n Averages: {averages}")
                print ("\n")
    return models

def eval_svc(train, silence_print = False, rw = None):
    eo_avgs = []
    acc_avgs = []
    tradeoff_avgs=[]
    models = {}
    
    for kernel in svm_kernels:
        for c in C:
            metrics, averages, ys, eq_opps = eval_k_fold(train, clf = SVC(kernel = kernel, C = c, gamma = g), rw = rw)
            models[f'{kernel}_SVC, c:{c}'] = {'averages':averages}
            models[f'{kernel}_SVC, c:{c}']['metrics'] = metrics
            models[f'{kernel}_SVC, c:{c}']['ys'] = ys
            models[f'{kernel}_SVC, c:{c}']['eq_opps'] = eq_opps

            if not silence_print:
                print (f"Results for SVC with C = {c}, gamma = {g} and kernel = {kernel} : \n \n Averages: {averages}")
                print ("\n")
    return models

# %%
C = [0.00001, 0.002, 0.1, 0.5, 1, 2, 5]
logreg_solvers = ['newton-cg', 'liblinear']
g = 'auto'
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']

svc_models = eval_svc(train)
logreg_models = eval_log_reg(train)
# Out:
# Results for SVC with C = 1e-05, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7611804487762357, 'avg_tradeoff': 0.880590224388118, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7611805942264068, 'avg_tradeoff': 0.8805902971132035, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7877387259754284, 'avg_tradeoff': 0.8830924821313193, 'mean_eq_opp': 0.0017860368592069408}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7877388029784601, 'avg_tradeoff': 0.8808220023333053, 'mean_eq_opp': 0.0022054832781169932}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7877385805252575, 'avg_tradeoff': 0.8785066264268803, 'mean_eq_opp': 0.0012844402124119192}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7877971456088402, 'avg_tradeoff': 0.884790969162634, 'mean_eq_opp': 0.001404422692470364}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.787738674640074, 'avg_tradeoff': 0.8848308412582748, 'mean_eq_opp': 0.0007265266309616991}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7611805300572136, 'avg_tradeoff': 0.8805902650286068, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7611803674952577, 'avg_tradeoff': 0.880590183747629, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.761180495833644, 'avg_tradeoff': 0.8805902479168222, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7968934880803371, 'avg_tradeoff': 0.7340709951119424, 'mean_eq_opp': -0.32875149785645247}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.804791158580343, 'avg_tradeoff': 0.6768749612940521, 'mean_eq_opp': -0.45104123599223894}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.8044983716639452, 'avg_tradeoff': 0.6688595416480851, 'mean_eq_opp': -0.4667792883677751}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.8044692260164326, 'avg_tradeoff': 0.6683416631930216, 'mean_eq_opp': -0.4677858996303893}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7611805043895364, 'avg_tradeoff': 0.8805902521947682, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7611804701659668, 'avg_tradeoff': 0.8805902350829833, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7887331302934505, 'avg_tradeoff': 0.8774647643829591, 'mean_eq_opp': -0.015025164513122613}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.8043230571504096, 'avg_tradeoff': 0.6682792955016941, 'mean_eq_opp': -0.4677644661470216}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.804323005815055, 'avg_tradeoff': 0.6683180220267578, 'mean_eq_opp': -0.46768696176153934}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.8043229074222923, 'avg_tradeoff': 0.6682641415792332, 'mean_eq_opp': -0.4677946242638259}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.8043229972591627, 'avg_tradeoff': 0.6682640659281557, 'mean_eq_opp': -0.4677948654028513}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7611803589393654, 'avg_tradeoff': 0.8805901794696827, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7611803033260646, 'avg_tradeoff': 0.8805901516630324, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7879142886098442, 'avg_tradeoff': 0.8800222850416513, 'mean_eq_opp': 0.002493613025696728}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7877388457579222, 'avg_tradeoff': 0.8783154617254454, 'mean_eq_opp': 0.0025409870917681545}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7877386446944504, 'avg_tradeoff': 0.8750257423631815, 'mean_eq_opp': 0.0023124542184042697}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7725583868001744, 'avg_tradeoff': 0.8102255857462172, 'mean_eq_opp': -0.07095242078053406}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.746965612114425, 'avg_tradeoff': 0.766393274875508, 'mean_eq_opp': -0.17273983274198368}
#
#
# Results for LogReg with C = 1e-05, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7611806498397076, 'avg_tradeoff': 0.8805903249198538, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7921554188124309, 'avg_tradeoff': 0.7686916858411852, 'mean_eq_opp': -0.2547720471300606}
#
#
# Results for LogReg with C = 0.1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.805259084614482, 'avg_tradeoff': 0.6752953493353535, 'mean_eq_opp': -0.4546683859437749}
#
#
# Results for LogReg with C = 0.5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.8054346087473817, 'avg_tradeoff': 0.6755049184993075, 'mean_eq_opp': -0.45442477174876694}
#
#
# Results for LogReg with C = 1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.8054343563485556, 'avg_tradeoff': 0.6759471736394889, 'mean_eq_opp': -0.453540009069578}
#
#
# Results for LogReg with C = 2, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.8057564386405833, 'avg_tradeoff': 0.6732024411310251, 'mean_eq_opp': -0.4593515563785333}
#
#
# Results for LogReg with C = 5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.805551507905452, 'avg_tradeoff': 0.672543423540139, 'mean_eq_opp': -0.4604646608251744}
#
#
# Results for LogReg with C = 1e-05, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.761180371773204, 'avg_tradeoff': 0.8805901858866019, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7938224360567895, 'avg_tradeoff': 0.756906227617755, 'mean_eq_opp': -0.2800099808212796}
#
#
# Results for LogReg with C = 0.1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.8050252050173636, 'avg_tradeoff': 0.6750275562194918, 'mean_eq_opp': -0.45497009257838006}
#
#
# Results for LogReg with C = 0.5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.8055223109225847, 'avg_tradeoff': 0.6719815416723434, 'mean_eq_opp': -0.461559227577898}
#
#
# Results for LogReg with C = 1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.8051710359256361, 'avg_tradeoff': 0.6732564866611708, 'mean_eq_opp': -0.45865806260329445}
#
#
# Results for LogReg with C = 2, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.8051711642640225, 'avg_tradeoff': 0.6703193519968673, 'mean_eq_opp': -0.4645324602702877}
#
#
# Results for LogReg with C = 5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.8052588621612792, 'avg_tradeoff': 0.6727142802714424, 'mean_eq_opp': -0.4598303016183943}

# %%
def select_best(models):
    best = 0
    best_key = ''
    for key in models.keys():
        if best < models[key]['averages']['avg_tradeoff']:
            best = models[key]['averages']['avg_tradeoff']
            best_key = key
        else:
            pass
    return best_key, best

def select_fair(models):
    best = 0
    best_key = ''
    for key in models.keys():
        if best < (1 - (abs(models[key]['averages']['mean_eq_opp']))):
            best = models[key]['averages']['mean_eq_opp']
            best_key = key
        else:
            pass
    return best_key, best

def select_acc(models):
    best = 0
    best_key = ''
    for key in models.keys():
        if best < models[key]['averages']['mean_acc']:
            best = models[key]['averages']['mean_acc']
            best_key = key
        else:
            pass
    return best_key, best

def better(lg, svc, lg_val, svc_val):
    if lg_val > svc_val:
        winner = lg
    elif lg_val < svc_val:
        winner = svc

    return winner

# %%
svc_best, svc_val = select_best(svc_models)
lg_best, lg_val = select_best(logreg_models)

svc_fair, svc_fair_val = select_fair(svc_models)
lg_fair, lg_fair_val = select_fair(logreg_models)

svc_acc, svc_acc_val = select_acc(svc_models)
lg_acc, lg_acc_val = select_acc(logreg_models)

print (better(lg_fair, svc_fair, lg_fair_val, svc_fair_val))
print (better(lg_acc, svc_acc, lg_acc_val, svc_acc_val))
print (better(lg_best, svc_best, lg_val, svc_val))
# Out:
# sigmoid_SVC, c:5
# newton-cg_LogReg_2
# linear_SVC, c:5

# %%
def test_selected_model(train, test, clf = None):
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(train.features)
    y_train = train.labels.ravel()
    X_test = scaler.transform(test.features)
    clf = clf
    clf.fit(X_train,y_train)
    predictions = clf.predict(X_test)
    test_pred = test.copy()
    test_pred.labels = predictions
    acc = sum(predictions==y_test)/len(y_test)
    metric = ClassificationMetric(test, test_pred, unprivileged_groups=unpriv, privileged_groups=priv)
    eo = (metric.equal_opportunity_difference())
    tradeoff = return_af_tradeoff(acc, eo)
    return acc, eo, tradeoff

# %%
best_standard_adult = test_selected_model(train, test, clf = SVC(kernel = 'linear', C =5, gamma='auto'))
fair_standard_adult = test_selected_model(train, test, clf = SVC(kernel = 'sigmoid', C =5, gamma='auto'))
accurate_standard_adult = test_selected_model(train, test, clf = LogisticRegression(solver = 'newton-cg', C =2))

# %% [markdown]
# ### Applying reweighting method

# %%
train, test = dataset_orig.split([0.7], shuffle=True)
rw = Reweighing(unprivileged_groups=unpriv,
                privileged_groups=priv)

rw_svc_models = eval_svc(train, silence_print = False, rw = rw) 
rw_logreg_models = eval_log_reg(train, silence_print = False, rw= rw)
# Out:
# Results for SVC with C = 1e-05, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7613267331468063, 'avg_tradeoff': 0.8806633665734032, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7613267245909139, 'avg_tradeoff': 0.8806633622954569, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7870367962837309, 'avg_tradeoff': 0.8754591435908019, 'mean_eq_opp': 0.015263651131620305}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7870365567187433, 'avg_tradeoff': 0.8845714187042297, 'mean_eq_opp': 0.016480646550506163}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7870659547650823, 'avg_tradeoff': 0.8851047835182758, 'mean_eq_opp': 0.01685638772853081}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7870659248194588, 'avg_tradeoff': 0.8818020055962885, 'mean_eq_opp': 0.017165966008489186}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7870367064468606, 'avg_tradeoff': 0.8797334666983087, 'mean_eq_opp': 0.01658378873181403}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7613266304760973, 'avg_tradeoff': 0.8806633152380486, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7613268486513539, 'avg_tradeoff': 0.880663424325677, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7613267374247525, 'avg_tradeoff': 0.8806633687123762, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7740788972207595, 'avg_tradeoff': 0.8352652632894593, 'mean_eq_opp': -0.10354837064184093}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7941735784374057, 'avg_tradeoff': 0.8209128512904906, 'mean_eq_opp': -0.15234787585642456}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7915703797229113, 'avg_tradeoff': 0.8603283181207033, 'mean_eq_opp': -0.07091374348150499}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7894642569680149, 'avg_tradeoff': 0.8874197236576336, 'mean_eq_opp': -0.010087988517907143}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.761326810149838, 'avg_tradeoff': 0.880663405074919, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7613266775335057, 'avg_tradeoff': 0.8806633387667528, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7870368903985476, 'avg_tradeoff': 0.8787698571907111, 'mean_eq_opp': 0.01713762545532751}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7870367192806993, 'avg_tradeoff': 0.8730056222072438, 'mean_eq_opp': 0.018283938945484957}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7870366551115062, 'avg_tradeoff': 0.8719141226588623, 'mean_eq_opp': 0.016585134334625516}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7883236538383466, 'avg_tradeoff': 0.8759039466965012, 'mean_eq_opp': 0.012056319995024368}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7896105413385857, 'avg_tradeoff': 0.8788351976975104, 'mean_eq_opp': 0.0032872282019547395}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7613265449171732, 'avg_tradeoff': 0.8806632724585868, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7613267630924297, 'avg_tradeoff': 0.8806633815462149, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7870657066442023, 'avg_tradeoff': 0.8815924311812628, 'mean_eq_opp': 0.016955544742555995}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7870368732867628, 'avg_tradeoff': 0.8783004447363378, 'mean_eq_opp': 0.016257438313447482}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7875337353490502, 'avg_tradeoff': 0.8817087381853776, 'mean_eq_opp': 0.0026623634022982733}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7686395185633561, 'avg_tradeoff': 0.7986562692411965, 'mean_eq_opp': 0.17132698008096314}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7504464528831496, 'avg_tradeoff': 0.8141866688249488, 'mean_eq_opp': 0.024938936647238875}
#
#
# Results for LogReg with C = 1e-05, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.761326810149838, 'avg_tradeoff': 0.880663405074919, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7653336671842552, 'avg_tradeoff': 0.8695664793528779, 'mean_eq_opp': 0.02620070847849935}
#
#
# Results for LogReg with C = 0.1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7901664561703236, 'avg_tradeoff': 0.8763605980126961, 'mean_eq_opp': 0.008041479602203394}
#
#
# Results for LogReg with C = 0.5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7895229931694461, 'avg_tradeoff': 0.8804506672505645, 'mean_eq_opp': 0.013529543708847425}
#
#
# Results for LogReg with C = 1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7897861681421945, 'avg_tradeoff': 0.8739445452971722, 'mean_eq_opp': 0.0013492430796293252}
#
#
# Results for LogReg with C = 2, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7899323712317872, 'avg_tradeoff': 0.881821024132926, 'mean_eq_opp': 0.007632630128000095}
#
#
# Results for LogReg with C = 5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7901955376486431, 'avg_tradeoff': 0.8790941588932106, 'mean_eq_opp': 0.005336517210876124}
#
#
# Results for LogReg with C = 1e-05, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7613268187057305, 'avg_tradeoff': 0.8806634093528652, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7552136934662458, 'avg_tradeoff': 0.749209528594964, 'mean_eq_opp': 0.25679463627631766}
#
#
# Results for LogReg with C = 0.1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7901958884402323, 'avg_tradeoff': 0.8823043567663096, 'mean_eq_opp': 0.004518719338903909}
#
#
# Results for LogReg with C = 0.5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7892890109016186, 'avg_tradeoff': 0.8854371795306305, 'mean_eq_opp': 0.000722007880312392}
#
#
# Results for LogReg with C = 1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7903711730081444, 'avg_tradeoff': 0.8834360993714, 'mean_eq_opp': -0.0024820181357224193}
#
#
# Results for LogReg with C = 2, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7902834622770489, 'avg_tradeoff': 0.8812138268309869, 'mean_eq_opp': 0.00431206595744923}
#
#
# Results for LogReg with C = 5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7902834109416945, 'avg_tradeoff': 0.8804071464006773, 'mean_eq_opp': 0.005101176443147793}

# %%
svc_acc, svc_acc_val = select_acc(rw_svc_models)
lg_acc, lg_acc_val = select_acc(rw_logreg_models)

svc_fair, svc_fair_val = select_fair(rw_svc_models)
lg_fair, lg_fair_val = select_fair(rw_logreg_models)

svc_best, svc_best_val = select_best(rw_svc_models)
lg_best, lg_best_val = select_best(rw_logreg_models)

print (better(lg_acc, svc_acc, lg_acc_val, svc_acc_val))
print (better(lg_fair, svc_fair, lg_fair_val, svc_fair_val))
print (better(lg_best, svc_best, lg_best_val, svc_best_val))
# Out:
# poly_SVC, c:1
# sigmoid_SVC, c:5
# poly_SVC, c:5

# %%
accurate_rw_adult = test_selected_model(train, test, clf = SVC(kernel = 'poly', C =1, gamma = 'auto'))
fair_rw_adult = test_selected_model(train, test, clf = SVC(kernel = 'sigmoid', C =5, gamma='auto'))
best_rw_adult = test_selected_model(train, test, clf = SVC(kernel = 'poly', C =5, gamma='auto'))

# %% [markdown]
# # Part II:  GermanDataset

# %%
# cd \usr\lib\aif360\data\raw\german

# %%
from aif360.datasets import GermanDataset
from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions import load_preproc_data_german

# %%
data = GermanDataset()
dataset_orig = load_preproc_data_german(['age', 'sex'])

# %%
priv = [{'age': 1, 'sex' : 1}]
unpriv = [{'age': 0, 'sex': 0}]
train, test = dataset_orig.split([0.7], shuffle=True)
scaler = MinMaxScaler()

# %%
C = [0.00001, 0.002, 0.1, 0.5, 1, 2, 5]
logreg_solvers = ['newton-cg', 'liblinear']
g = 'auto'
svm_kernels = ['linear', 'poly', 'rbf', 'sigmoid']

# %%
logreg_models_german = eval_log_reg(train, silence_print = False)
svc_models_german = eval_svc(train, silence_print = False)
# Out:
# Results for LogReg with C = 1e-05, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7042857142857143, 'avg_tradeoff': 0.814642857142857, 'mean_eq_opp': -0.075}
#
#
# Results for LogReg with C = 0.5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.71, 'avg_tradeoff': 0.7367316017316017, 'mean_eq_opp': -0.23653679653679652}
#
#
# Results for LogReg with C = 1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7128571428571429, 'avg_tradeoff': 0.6697619047619048, 'mean_eq_opp': -0.37333333333333335}
#
#
# Results for LogReg with C = 2, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7071428571428571, 'avg_tradeoff': 0.6841117216117215, 'mean_eq_opp': -0.33891941391941394}
#
#
# Results for LogReg with C = 5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7057142857142856, 'avg_tradeoff': 0.6778571428571428, 'mean_eq_opp': -0.35}
#
#
# Results for LogReg with C = 1e-05, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7000000000000001, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.71, 'avg_tradeoff': 0.67, 'mean_eq_opp': -0.37}
#
#
# Results for LogReg with C = 0.5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.71, 'avg_tradeoff': 0.7474062049062049, 'mean_eq_opp': -0.2151875901875902}
#
#
# Results for LogReg with C = 1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7085714285714285, 'avg_tradeoff': 0.7447619047619047, 'mean_eq_opp': -0.21904761904761907}
#
#
# Results for LogReg with C = 2, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.6971428571428572, 'avg_tradeoff': 0.7398412698412699, 'mean_eq_opp': -0.2174603174603175}
#
#
# Results for LogReg with C = 5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7128571428571429, 'avg_tradeoff': 0.759484126984127, 'mean_eq_opp': -0.1938888888888889}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7000000000000002, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = poly :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.7000000000000001, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = rbf :
#
#  Averages: {'mean_acc': 0.702857142857143, 'avg_tradeoff': 0.8514285714285714, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.002, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7000000000000001, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.1, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7000000000000001, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 0.5, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 1, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 2, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.85, 'mean_eq_opp': 0.0}
#
#
# Results for SVC with C = 5, gamma = auto and kernel = sigmoid :
#
#  Averages: {'mean_acc': 0.7, 'avg_tradeoff': 0.8375, 'mean_eq_opp': -0.025}

# %%
svc_best, svc_val = select_best(svc_models_german)
lg_best, lg_val = select_best(logreg_models_german)

svc_fair, svc_fair_val = select_fair(svc_models_german)
lg_fair, lg_fair_val = select_fair(logreg_models_german)

svc_acc, svc_acc_val = select_acc(svc_models_german)
lg_acc, lg_acc_val = select_acc(logreg_models_german)

print (better(lg_acc, svc_acc, lg_acc_val, svc_acc_val))
print (better(lg_fair, svc_fair, lg_fair_val, svc_fair_val))
print (better(lg_best, svc_best, lg_best_val, svc_best_val))
# Out:
# newton-cg_LogReg_1
# sigmoid_SVC, c:5
# rbf_SVC, c:5

# %%
best_standard_german = test_selected_model(train, test, clf = SVC(kernel = 'rbf', C =5))
fair_standard_german = test_selected_model(train, test, clf = SVC(kernel = 'sigmoid', C =5, gamma = 'auto'))
accurate_standard_german = test_selected_model(train, test, LogisticRegression(solver = 'newton-cg', C =1))

# %%
train, test = dataset_orig.split([0.7], shuffle=True)
rw = Reweighing(unprivileged_groups=unpriv,
                privileged_groups=priv)
rw_logreg_models_german = eval_log_reg(train, silence_print = False, rw = rw)
rw_svc_models_german = eval_svc(train, silence_print = False, rw = rw)
# Out:
# Results for LogReg with C = 1e-05, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.760478839930504, 'avg_tradeoff': 0.880239419965252, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7710371705184652, 'avg_tradeoff': 0.8803105407010469, 'mean_eq_opp': -0.010416089116371634}
#
#
# Results for LogReg with C = 0.1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7904586570080908, 'avg_tradeoff': 0.8823027010358657, 'mean_eq_opp': 0.012094496453721492}
#
#
# Results for LogReg with C = 0.5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7914535532899267, 'avg_tradeoff': 0.8759903101849469, 'mean_eq_opp': -0.025273719317228528}
#
#
# Results for LogReg with C = 1, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7903417022367198, 'avg_tradeoff': 0.885165170496075, 'mean_eq_opp': 0.009887582928353945}
#
#
# Results for LogReg with C = 2, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7905468939265698, 'avg_tradeoff': 0.8813997250007299, 'mean_eq_opp': 0.00895286141999213}
#
#
# Results for LogReg with C = 5, and solver = newton-cg :
#
#  Averages: {'mean_acc': 0.7902543123515899, 'avg_tradeoff': 0.881734381300965, 'mean_eq_opp': 0.01139783090166625}
#
#
# Results for LogReg with C = 1e-05, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7604786730906018, 'avg_tradeoff': 0.8802393365453008, 'mean_eq_opp': 0.0}
#
#
# Results for LogReg with C = 0.002, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7551845178731094, 'avg_tradeoff': 0.7534170906406202, 'mean_eq_opp': 0.2483503365918692}
#
#
# Results for LogReg with C = 0.1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7880604489199746, 'avg_tradeoff': 0.8716220831545035, 'mean_eq_opp': 0.03888360378908817}
#
#
# Results for LogReg with C = 0.5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.790546692863098, 'avg_tradeoff': 0.8871917754197355, 'mean_eq_opp': 0.007878797425058249}
#
#
# Results for LogReg with C = 1, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7905467698661297, 'avg_tradeoff': 0.880772992152357, 'mean_eq_opp': 0.007757447742803658}
#
#
# Results for LogReg with C = 2, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7905466586395284, 'avg_tradeoff': 0.8858945475053235, 'mean_eq_opp': 0.00863490580929398}
#
#
# Results for LogReg with C = 5, and solver = liblinear :
#
#  Averages: {'mean_acc': 0.7905465859144429, 'avg_tradeoff': 0.8845915374022637, 'mean_eq_opp': 0.008677300261940224}
#
#
# Results for SVC with C = 1e-05, gamma = auto and kernel = linear :
#
#  Averages: {'mean_acc': 0.7604787287039025, 'avg_tradeoff': 0.8802393643519512, 'mean_eq_opp': 0.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21408\1146260139.py in <module>
#       3                 privileged_groups=priv)
#       4 rw_logreg_models_german = eval_log_reg(train, silence_print = False, rw = rw)
# ----> 5 rw_svc_models_german = eval_svc(train, silence_print = False, rw = rw)
#
# ~\AppData\Local\Temp\ipykernel_21408\3032617173.py in eval_svc(train, silence_print, rw)
#      26     for kernel in svm_kernels:
#      27         for c in C:
# ---> 28             metrics, averages, ys, eq_opps = eval_k_fold(train, clf = SVC(kernel = kernel, C = c, gamma = g), rw = rw)
#      29             models[f'{kernel}_SVC, c:{c}'] = {'averages':averages}
#      30             models[f'{kernel}_SVC, c:{c}']['metrics'] = metrics
#
# ~\AppData\Local\Temp\ipykernel_21408\627938973.py in eval_k_fold(train, clf, rw, k)
#      37         X_test = scaler.transform(k_test.features)
#      38         y_test = k_test.labels.ravel()
# ---> 39         clf.fit(X_train, y_train, sample_weight = sw)
#      40         predictions = clf.predict(k_test.features)
#      41         test_pred = k_test.copy()
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %%
svc_best, svc_val = select_best(rw_svc_models_german)
lg_best, lg_val = select_best(rw_logreg_models_german)

svc_fair, svc_fair_val = select_fair(rw_svc_models_german)
lg_fair, lg_fair_val = select_fair(rw_logreg_models_german)

svc_acc, svc_acc_val = select_acc(rw_svc_models_german)
lg_acc, lg_acc_val = select_acc(rw_logreg_models_german)


print (better(lg_acc, svc_acc, lg_acc_val, svc_acc_val))
print (better(lg_fair, svc_fair, lg_fair_val, svc_fair_val))
print (better(lg_best, svc_best, lg_best_val, svc_best_val))
# Out:
# newton-cg_LogReg_0.5
# sigmoid_SVC, c:5
# poly_SVC, c:0.002

# %%
accurate_rw_german = test_selected_model(train, test, clf = LogisticRegression(solver = 'newton-cg', C =0.5))
fair_rw_german = test_selected_model(train, test, clf = SVC(kernel = 'linear', C =5, gamma='auto'))
best_rw_german = test_selected_model(train, test, clf = SVC(kernel = 'poly', C =0.002, gamma='auto'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21408\1599102088.py in <module>
#       1 accurate_rw_german = test_selected_model(train, test, clf = LogisticRegression(solver = 'newton-cg', C =0.5))
# ----> 2 fair_rw_german = test_selected_model(train, test, clf = SVC(kernel = 'linear', C =5, gamma='auto'))
#       3 best_rw_german = test_selected_model(train, test, clf = SVC(kernel = 'poly', C =0.002, gamma='auto'))
#       4
#
# ~\AppData\Local\Temp\ipykernel_21408\3462038636.py in test_selected_model(train, test, clf)
#       5     X_test = scaler.transform(test.features)
#       6     clf = clf
# ----> 7     clf.fit(X_train,y_train)
#       8     predictions = clf.predict(X_test)
#       9     test_pred = test.copy()
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %%
final_reports_adult = {'Standard_Fair': {'Sigmoid_SVC, C = 5':fair_standard_adult}, 'Standard_Accurate': {'poly_SVC, C = 1': accurate_standard_adult}, 'Standard_Best':{'Poly_SVC, C = 5':best_standard_adult} , 'RW_Fair':{'Sigmoid_SVC, C = 5':fair_rw_adult} , 'RW_Accurate':{'Poly_SVC, C = 5':accurate_rw_adult} , 'RW_Best':{'Poly_SVC, C = 5':best_rw_adult} }
final_reports_german = {'Standard_Fair': {'Sigmoid_SVC, C=5':fair_standard_german}, 'Standard_Accurate': {'Newton-cg_LogReg, C=1': accurate_standard_german}, 'Standard_Best':{'rbf_SVC, C=5':best_standard_german} , 'RW_Fair':{'Sigmoid_SVC, C=0.5':fair_rw_german} , 'RW_Accurate':{'Newton-cg_LogReg, C= 0.5':accurate_rw_german} , 'RW_Best':{'Poly_SVC, C=0.002':best_rw_german} }

# %%
df_adult = pd.DataFrame.from_dict(final_reports_adult)
df_german = pd.DataFrame.from_dict(final_reports_german)

# %%
df_adult.T
# Out:
#                                                   Sigmoid_SVC, C = 5  \
# Standard_Fair      (0.6617757455811096, -0.09851645964232264, 0.7...
# Standard_Accurate                                                NaN
# Standard_Best                                                    NaN
# RW_Fair            (0.6617757455811096, -0.09851645964232264, 0.7...
# RW_Accurate                                                      NaN
# RW_Best                                                          NaN
#
#                                                      poly_SVC, C = 1  \
# Standard_Fair                                                    NaN
# Standard_Accurate  (0.6908482904524671, -0.44508279824264957, 0.6...
# Standard_Best                                                    NaN
# RW_Fair                                                          NaN
# RW_Accurate                                                      NaN
# RW_Best                                                          NaN
#
#                                                      Poly_SVC, C = 5
# Standard_Fair                                                    NaN
# Standard_Accurate                                                NaN
# Standard_Best      (0.6584999658772948, -0.008779855301363548, 0....
# RW_Fair                                                          NaN
# RW_Accurate        (0.6901658363475056, -0.44711051030753635, 0.6...
# RW_Best            (0.6859346208967447, -0.45927678269685707, 0.6...

# %%
df_german.T
# Out:
#                                                     Sigmoid_SVC, C=5  \
# Standard_Fair      (0.6617757455811096, -0.09851645964232264, 0.7...
# Standard_Accurate                                                NaN
# Standard_Best                                                    NaN
# RW_Fair                                                          NaN
# RW_Accurate                                                      NaN
# RW_Best                                                          NaN
#
#                                                Newton-cg_LogReg, C=1  \
# Standard_Fair                                                    NaN
# Standard_Accurate  (0.6908482904524671, -0.44508279824264957, 0.6...
# Standard_Best                                                    NaN
# RW_Fair                                                          NaN
# RW_Accurate                                                      NaN
# RW_Best                                                          NaN
#
#                                                         rbf_SVC, C=5  \
# Standard_Fair                                                    NaN
# Standard_Accurate                                                NaN
# Standard_Best      (0.6890056643690712, -0.454883406556269, 0.617...
# RW_Fair                                                          NaN
# RW_Accurate                                                      NaN
# RW_Best                                                          NaN
#
#                                                   Sigmoid_SVC, C=0.5  \
# Standard_Fair                                                    NaN
# Standard_Accurate                                                NaN
# Standard_Best                                                    NaN
# RW_Fair            (0.6584999658772948, -0.008779855301363548, 0....
# RW_Accurate                                                      NaN
# RW_Best                                                          NaN
#
#                                             Newton-cg_LogReg, C= 0.5  \
# Standard_Fair                                                    NaN
# Standard_Accurate                                                NaN
# Standard_Best                                                    NaN
# RW_Fair                                                          NaN
# RW_Accurate        (0.6908482904524671, -0.44508279824264957, 0.6...
# RW_Best                                                          NaN
#
#                                                Poly_SVC, C=0.002
# Standard_Fair                                                NaN
# Standard_Accurate                                            NaN
# Standard_Best                                                NaN
# RW_Fair                                                      NaN
# RW_Accurate                                                  NaN
# RW_Best            (0.7624377260629223, 0.0, 0.8812188630314611)

# %% [markdown]
# ### Model Selection
